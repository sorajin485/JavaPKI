# %% [markdown]
# <a href="https://colab.research.google.com/github/sorajin485/JavaPKI/blob/master/bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### import 및 폰트추가 , 구글인증

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm  # 폰트 관련 용도

# %%
#시스템에 설치되어 있는 폰트확인
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
# Out:
# sys_font number: 16
# ...

# %%
#나눔 폰트 다운로
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 130912 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
# Out:
# sys_font number: 47
# nanum_font number: 31

# %%
# 한번 프린트 해보자
nanum_font
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumPen.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBrush.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundEB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEcoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareEB.ttf',
# ...

# %%
# !python --version
def current_font():
  print(f"설정 폰트 글꼴: {plt.rcParams['font.family']}, 설정 폰트 사이즈: {plt.rcParams['font.size']}")  # 파이썬 3.6 이상 사용가능하다
        
current_font()
# Out:
# Python 3.6.7
# 설정 폰트 글꼴: ['sans-serif'], 설정 폰트 사이즈: 10.0

# %%
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
# Out:
# NanumGothic Eco

# %%
fm._rebuild()

# %%
matplotlib.rcParams['font.family'].insert(0, 'Malgun Gothic')

# %% [markdown]
# ###테스트

# %%
#data3000 = pd.read_excel('data/1981.xlsx')
#data3000
#전체 데이터 가져오기
data1979 = pd.read_excel('data/1979.xlsx')
data1979.head()
data1980 = pd.read_excel('data/1980.xlsx')
data1980.head()
data1981 = pd.read_excel('data/1981.xlsx')
data1981.head()
data1982 = pd.read_excel('data/1982.xlsx')
data1982.head()
data1983 = pd.read_excel('data/1983.xlsx')
data1983.head()
data1984 = pd.read_excel('data/1984.xlsx')
data1984.head()
data1985 = pd.read_excel('data/1985.xlsx')
data1985.head()
data1986 = pd.read_excel('data/1986.xlsx')
data1986.head()
data1987 = pd.read_excel('data/1987.xlsx')
data1987.head()
data1988 = pd.read_excel('data/1988.xlsx')
data1988.head()
data1989 = pd.read_excel('data/1989.xlsx')
data1989.head()
data1990 = pd.read_excel('data/1990.xlsx')
data1990.head()
data1991 = pd.read_excel('data/1991.xlsx')
data1991.head()
data1992 = pd.read_excel('data/1992.xlsx')
data1992.head()
data1993 = pd.read_excel('data/1993.xlsx')
data1993.head()
data1994 = pd.read_excel('data/1994.xlsx')
data1994.head()
data1995 = pd.read_excel('data/1995.xlsx')
data1995.head()
data1996 = pd.read_excel('data/1996.xlsx')
data1996.head()
data1997 = pd.read_excel('data/1997.xlsx')
data1997.head()
data1998 = pd.read_excel('data/1998.xlsx')
data1998.head()
data1999 = pd.read_excel('data/1999.xlsx')
data1999.head()
data2000 = pd.read_excel('data/2000.xlsx')
data2000.head()
data2001 = pd.read_excel('data/2001.xlsx')
data2001.head()
data2002 = pd.read_excel('data/2002.xlsx')
data2002.head()
data2003 = pd.read_excel('data/2003.xlsx')
data2003.head()
data2004 = pd.read_excel('data/2004.xlsx')
data2004.head()
data2005 = pd.read_excel('data/2005.xlsx')
data2005.head()
data2006 = pd.read_excel('data/2006.xlsx')
data2006.head()
data2007 = pd.read_excel('data/2007.xlsx')
data2007.head()
data2008 = pd.read_excel('data/2008.xlsx')
data2008.head()
data2009 = pd.read_excel('data/2009.xlsx')
data2009.head()
data2010 = pd.read_excel('data/2010.xlsx')
data2010.head()
data2011 = pd.read_excel('data/2011.xlsx')
data2011.head()
data2012 = pd.read_excel('data/2012.xlsx')
data2012.head()
data2013 = pd.read_excel('data/2013.xlsx')
data2013.head()
data2014 = pd.read_excel('data/2014.xlsx')
data2014.head()
data2015 = pd.read_excel('data/2015.xlsx')
data2015.head()
data2016 = pd.read_excel('data/2016.xlsx')
data2016.head()
data2017 = pd.read_excel('data/2017.xlsx')
data2017.head()
data2018 = pd.read_excel('data/2018.xlsx')
data2018.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-ff18fad1061a> in <module>()
# ----> 1 data1979 = pd.read_excel('data/1979.xlsx')
#       2 data1979.head()
#       3 data1980 = pd.read_excel('data/1980.xlsx')
#       4 data1980.head()
#       5 data1981 = pd.read_excel('data/1981.xlsx')
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
# ...

# %%
# !dir
# Out:
# adc.json  gdrive  sample_data

# %% [markdown]
# ###작업공간

# %% [markdown]
# ####데이터 불러오기
# #구글드라이브 기온데이터

# %%
#모든 데이터값 가져오기
DataArr= [] 
for i in range(1979,2020,1):
    DataArr.append(pd.read_excel('./gdrive/My Drive/data/{0}.xlsx'.format(i)))

# %%
DataArr[40].head(2)
# Out:
#     지점         일시  평균기온  최저기온  최고기온
# 0  108 2019-01-01  -5.0  -8.2  -0.6
# 1  108 2019-01-02  -4.9  -8.8   0.2

# %%
#d2018 = DataFrame(data2018)
#d2018 = d2018[['일시','평균기온','최저기온','최고기온']]
#d2018 = d2018.set_index('일시')
#d2018.head()

# %% [markdown]
# ####데이터 셋 만들기
# #인덱스 : 일시 , 컬럼 : 평균기온,최저기온,최고기온

# %%
DataArrFrame= []
for i in range(0,41,1):
    DataArrFrame.append(DataFrame(DataArr[i]))
    DataArrFrame[i]=DataArrFrame[i][['일시','평균기온','최저기온','최고기온']]
    DataArrFrame[i]=DataArrFrame[i].set_index('일시')

# %%
DataArrFrame[40].head()
# Out:
#             평균기온  최저기온  최고기온
# 일시
# 2019-01-01  -5.0  -8.2  -0.6
# 2019-01-02  -4.9  -8.8   0.2
# 2019-01-03  -3.5  -8.4   3.2
# 2019-01-04  -1.1  -6.2   4.1
# 2019-01-05  -2.8  -5.5   1.1

# %%
DataArrFrame[0].plot(figsize=(12,8))

# %%
DataArrFrame[0].loc['1979-09-01':'1979-11-30'].plot()

# %%
Spring8.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='8년 기준 봄데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-fc0d0dd3d4e5> in <module>()
# ----> 1 Spring8.plot(kind='line',
#       2        style=['ko--','bo--','ro--'],
#       3        subplots=False,
#       4        title='8년 기준 봄데이터',
#       5        figsize=(12,8),
#
# NameError: name 'Spring8' is not defined

# %% [markdown]
# ####데이터 셋 합치기  #년도별 + 일별 봄, 가을나누기

# %%
#DataArr[0].head()

# %%
#test2018 = d2018
#test2018 = test2018.loc['2018-03-01':'2018-05-31']
#test2018.plot()
#year=1979
#Spring=DataArrFrame[0].loc['{0}-03-01'.format(str(year)):'{0}-05-31'.format(str(year))]
#Spring
#SpringArr.append(Spring)
#SpringArr[0]

# %%
SpringArr= []
SummerArr=[]
FallArr=[]
WinterArr=[]
year=1978
for i in range(0,40,1):
    year+=1
    WinterArr2=[]
    SpringArr.append(DataArrFrame[i].loc['{0}-03-01'.format(str(year)):'{0}-05-31'.format(str(year))])
    SummerArr.append(DataArrFrame[i].loc['{0}-06-01'.format(str(year)):'{0}-08-31'.format(str(year))])
    FallArr.append(DataArrFrame[i].loc['{0}-09-01'.format(str(year)):'{0}-11-30'.format(str(year))])
    WinterArr.append(DataArrFrame[i].loc['{0}-12-01'.format(str(year)):'{0}-12-31'.format(str(year))])
    WinterArr2.append(DataArrFrame[i+1].loc['{0}-01-01'.format(str(year+1)):'{0}-02-28'.format(str(year+1))])
    WinterArr[i]=pd.concat([WinterArr[i],WinterArr2[0]])
    #WinterArr[i]=pd.concat([WinterArr,DataArrFrame[i+1].loc['{0}-01-01'.format(str(year)):'{0}-02-28'.format(str(year))]],axis=1)

# %% [markdown]
# #####데이터 테스트

# %%
SummerArr[0].head()
# Out:
#             평균기온  최저기온  최고기온
# 일시
# 1979-06-01  21.8  16.4  28.0
# 1979-06-02  20.7  16.3  25.5
# 1979-06-03  19.4  16.2  23.4
# 1979-06-04  22.7  18.8  26.7
# 1979-06-05  21.0  19.8  23.6

# %%
SummerArr.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f39f8149820b> in <module>()
# ----> 1 SummerArr.plot()
#
# AttributeError: 'list' object has no attribute 'plot'

# %%
SpringArr[0].head()

# %%
FallArr[0].head(1)
# Out:
#             평균기온  최저기온  최고기온
# 일시
# 1979-09-01  21.1  20.3  22.4

# %%
FallArr[0].plot()

# %%
WinterArr[39].head(3)
# Out:
#             평균기온  최저기온  최고기온
# 일시
# 2018-12-01   5.5   0.8  12.4
# 2018-12-02   8.2   2.8  11.8
# 2018-12-03  11.5   9.3  13.5

# %% [markdown]
# ####데이터셋 가공 #1년,4년,8년
# #년도별 봄,가을 평균값 : 평균기온, 최저기온, 최고기온

# %% [markdown]
# #####데이터셋 가공

# %%
year=1978
SpringYearsData=[]
SummerYearsData=[]
FallYearsData=[]
WinterYearsData=[]
for i in range(0,40,1):
    year +=1
    SpringYearsData.append(DataFrame({'{}'.format(str(year)):round(SpringArr[i].sum(axis=0)/92,1)}))
    SummerYearsData.append(DataFrame({'{}'.format(str(year)):round(SummerArr[i].sum(axis=0)/92,1)}))
    FallYearsData.append(DataFrame({'{}'.format(str(year)):round(FallArr[i].sum(axis=0)/91,1)}))
    WinterYearsData.append(DataFrame({'{}'.format(str(year)):round(WinterArr[i].sum(axis=0)/90,1)}))

# %%
DataFrame(SpringYearsData[0])
# Out:
#       1979
# 평균기온  11.2
# 최저기온   6.8
# 최고기온  16.6

# %%
FallYearsData[1]
# Out:
#       1980
# 평균기온  13.7
# 최저기온   9.2
# 최고기온  19.0

# %% [markdown]
# #####1년 4년 8년

# %%
#초기화
Spring=SpringYearsData[0]
Summer=SummerYearsData[0]
Fall=FallYearsData[0]
Winter=WinterYearsData[0]

Spring4=[]
Summer4=[]
Fall4=[]
Winter4=[]

Spring8=[]
Summer8=[]
Fall8=[]
Winter8=[]
#1년
for i in range(1,40,1):
    Spring=pd.concat([Spring,SpringYearsData[i]],axis=1)
    Summer=pd.concat([Spring,SpringYearsData[i]],axis=1)
    Fall=pd.concat([Fall,FallYearsData[i]],axis=1)
    Winter=pd.concat([Winter,WinterYearsData[i]],axis=1)
#4년
#봄, 여름, 가을 4년치 데이터셋
#Spring4, Summer4, Fall4, Winter4
year=1975
for i in range(0,40,4):#1979,1982
    year+=4
    Spring4.append(Spring.T.loc['{0}'.format(year):'{0}'.format(year+3)].mean())
    Summer4.append(Summer.T.loc['{0}'.format(year):'{0}'.format(year+3)].mean())
    Fall4.append(Fall.T.loc['{0}'.format(year):'{0}'.format(year+3)].mean())
    Winter4.append(Winter.T.loc['{0}'.format(year):'{0}'.format(year+3)].mean())
Spring4=DataFrame(Spring4)
Spring4=Spring4.rename(index={0:'1979~1982',1:'1983~1986',2:'1987~1990',3:'1991~1994',4:'1995~1998',5:'1999~2002',6:'2003~2006',7:'2007~2010',8:'2011~0214',9:'2015~2018'})

Summer4=DataFrame(Summer4)
Summer4=Summer4.rename(index={0:'1979~1982',1:'1983~1986',2:'1987~1990',3:'1991~1994',4:'1995~1998',5:'1999~2002',6:'2003~2006',7:'2007~2010',8:'2011~0214',9:'2015~2018'})

Fall4=DataFrame(Fall4)
Fall4=Fall4.rename(index={0:'1979~1982',1:'1983~1986',2:'1987~1990',3:'1991~1994',4:'1995~1998',5:'1999~2002',6:'2003~2006',7:'2007~2010',8:'2011~0214',9:'2015~2018'})

Winter4=DataFrame(Winter4)
Winter4=Winter4.rename(index={0:'1979~1982',1:'1983~1986',2:'1987~1990',3:'1991~1994',4:'1995~1998',5:'1999~2002',6:'2003~2006',7:'2007~2010',8:'2011~0214',9:'2015~2018'})

#Winter4=DataFrame(Winter4)
#Winter4=Winter4.rename(index={0:'1979~1982',1:'1983~1986',2:'1987~1990',3:'1991~1994',4:'1995~1998',5:'1999~2002',6:'2003~2006',7:'2007~2010',8:'2011~0214',9:'2015~2018'})
#/Spring4, Summer4, Fall4, Winter4

#8년 봄, 여름, 가을 8년치 데이터셋
#Spring8, Summer8, Fall8
year=1971
for i in range(0,40,8):#1979,1986
    year+=8
    Spring8.append(Spring.T.loc['{0}'.format(year):'{0}'.format(year+7)].mean())
    Summer8.append(Summer.T.loc['{0}'.format(year):'{0}'.format(year+7)].mean())
    Fall8.append(Fall.T.loc['{0}'.format(year):'{0}'.format(year+7)].mean())
    Winter8.append(Winter.T.loc['{0}'.format(year):'{0}'.format(year+7)].mean())
Spring8=DataFrame(Spring8)
Spring8=Spring8.rename(index={0:'1979~1986',1:'1987~1994',2:'1995~2002',3:'2003~2010',4:'2011~2018'})

Summer8=DataFrame(Summer8)
Summer8=Summer8.rename(index={0:'1979~1986',1:'1987~1994',2:'1995~2002',3:'2003~2010',4:'2011~2018'})

Fall8=DataFrame(Fall8)
Fall8=Fall8.rename(index={0:'1979~1986',1:'1987~1994',2:'1995~2002',3:'2003~2010',4:'2011~2018'})

Winter8=DataFrame(Winter8)
Winter8=Winter8.rename(index={0:'1979~1986',1:'1987~1994',2:'1995~2002',3:'2003~2010',4:'2011~2018'})
#/Spring8, Summer8, Fall8, Winter8

# %% [markdown]
# #####시각화 테스트

# %%
Spring.T.head(3)
# Out:
#       평균기온  최저기온  최고기온
# 1979  11.2   6.8  16.6
# 1980  10.6   6.1  16.1
# 1981  11.1   6.5  16.7

# %%
Spring.T.plot()

# %%
Spring4.head(3)
# Out:
#              평균기온   최저기온    최고기온
# 1979~1982  11.225  6.750  16.675
# 1983~1986  11.600  6.925  17.050
# 1987~1990  11.525  7.075  16.650

# %%
Spring4.plot()

# %%
Spring8.head(3)
# Out:
#               평균기온    최저기온     최고기온
# 1979~1986  11.4125  6.8375  16.8625
# 1987~1994  11.7250  7.2000  16.9375
# 1995~2002  12.4000  7.8125  17.4750

# %%
Spring8.plot()

# %%
Summer.T.plot()

# %%
Summer4.plot()

# %%
Summer8.plot()

# %%
Fall.T.plot()

# %%
Fall4.plot()

# %%
Fall8.plot()

# %%
Winter.T.plot()

# %%
Winter8.plot()

# %% [markdown]
# #####시각화 메인

# %% [markdown]
# #####기준
# #1년 봄 여름 가을 겨울

# %%
Spring.T.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='1년 기준 봄데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Summer.T.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='1년 기준 여름데이터',
       figsize=(12,8),
       fontsize=13
       )
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Fall.T.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='1년 기준 가을데이터',
       figsize=(12,8),
       fontsize=13
       )
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Winter.T.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='1년 기준 겨울데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %% [markdown]
# #4년

# %%
Spring4.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='4년 기준 봄데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Summer4.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='4년 기준 여름데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Fall4.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='4년 기준 가을데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Winter4.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='4년 기준 겨울데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %% [markdown]
# #8년

# %%
Spring8.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='8년 기준 봄데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Summer8.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='8년 기준 여름데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Fall8.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='8년 기준 가데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %%
Winter8.plot(kind='line',
       style=['ko--','bo--','ro--'],
       subplots=False,
       title='8년 기준 겨울데이터',
       figsize=(12,8),
       fontsize=13
       )
#plt.title('봄, 가을은 사라지고 있는가')
plt.ylabel('기온')
plt.xlabel('연도')
#plt.style.use('seaborn-pastel')
plt.show()

# %% [markdown]
# #####TEST
# #TEST

# %%
#3년
for i in range(1,40,3):
    Spring3=pd.concat([Spring3,SpringYearsData[i],SpringYearsData[i+1],SpringYearsData[i+2]],axis=1)
    Fall3=pd.concat([Fall3,FallYearsData[i],FallYearsData[i+1],FallYearsData[i+2]],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-5a8090d3ff5a> in <module>()
#       1 for i in range(1,40,3):
# ----> 2     Spring3=pd.concat([Spring3,SpringYearsData[i],SpringYearsData[i+1],SpringYearsData[i+2]],axis=1)
#       3     Fall3=pd.concat([Fall3,FallYearsData[i],FallYearsData[i+1],FallYearsData[i+2]],axis=1)
#
# NameError: name 'Spring3' is not defined

# %%
#test=FallYearsData[0].T[['평균기온']]+FallYearsData[1].T[['평균기온']]
#test
#test=(FallYearsData[0]['평균기온']+FallYearsData[1]['평균기온']+FallYearsData[2]['평균기온'],axis=0)

#pd.concat([SpringYearsData[0],SpringYearsData[1]],axis=1)
#for i in range(1,40,1):
#    SpringYearsData[0]=pd.concat([SpringYearsData[0],SpringYearsData[i]],axis=1)

# %%
Spring3.T

# %%
#봄,가을 5년치 데이터셋
year=1974
Spring5=[]
for i in range(0,40,5):#1979,1983
    year+=5
    Spring5.append(Spring.T.loc['{0}'.format(year):'{0}'.format(year+4)].mean())
Spring5=DataFrame(Spring5)
Spring5=Spring5.rename(index={0:'1979~1983',1:'1984~1988',2:'1989~1993',3:'1994~1998',4:'1999~2003',5:'2004~2008',6:'2009~2013',7:'2014~2018'})
#Spring5
year=1974
Fall5=[]
for i in range(0,40,5):
    year+=5
    Fall5.append(Fall.T.loc['{0}'.format(year):'{0}'.format(year+4)].mean())
Fall5=DataFrame(Fall5)
Fall5=Fall5.rename(index={0:'1979~1983',1:'1984~1988',2:'1989~1993',3:'1994~1998',4:'1999~2003',5:'2004~2008',6:'2009~2013',7:'2014~2018'})
#Fall5

# %%
#봄,가을 4년치 데이터셋
year=1975
Spring4=[]
for i in range(0,40,4):#1979,1982
    year+=4
    Spring4.append(Spring.T.loc['{0}'.format(year):'{0}'.format(year+3)].mean())
Spring4=DataFrame(Spring4)
Spring4=Spring4.rename(index={0:'1979~1982',1:'1983~1986',2:'1987~1990',3:'1991~1994',4:'1995~1998',5:'1999~2002',6:'2003~2006',7:'2007~2010',8:'2011~0214',9:'2015~2018'})
#Spring4
year=1975
Fall4=[]
for i in range(0,40,4):
    year+=4
    Fall4.append(Fall.T.loc['{0}'.format(year):'{0}'.format(year+3)].mean())
Fall4=DataFrame(Fall4)
Fall4=Fall4.rename(index={0:'1979~1982',1:'1983~1986',2:'1987~1990',3:'1991~1994',4:'1995~1998',5:'1999~2002',6:'2003~2006',7:'2007~2010',8:'2011~0214',9:'2015~2018'})
#Fall4

# %%
Spring4

# %%
Fall4

# %%
Spring5.T

# %%
Spring
# Out:
#       1979  1980  1981  1982  1983  1984  ...  2013  2014  2015  2016  2017  2018
# 평균기온  11.2  10.6  11.1  12.0  12.8  10.9  ...  11.1  13.6  12.8  13.6  13.2  13.1
# 최저기온   6.8   6.1   6.5   7.6   7.9   6.5  ...   6.7   8.9   7.6   8.5   8.4   8.4
# 최고기온  16.6  16.1  16.7  17.3  18.0  16.4  ...  16.5  19.3  18.7  19.5  19.2  18.5
#
# [3 rows x 40 columns]

# %%
Fall5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-8dbddf7b64f6> in <module>()
# ----> 1 Fall5
#
# NameError: name 'Fall5' is not defined

# %%
Spring.T.plot() #년도별 봄 평균기온,최저기온,최고기온

# %%
Fall.T.plot(kind='line',subplots = True,figsize=(10,20)) #년도별 가을 평균기온, 최저기온, 최고기온
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb732350128>,
# ...
#       dtype=object)

# %%
Spring5.plot(subplots = True,figsize=(10,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-86f54e7b35f3> in <module>()
# ----> 1 Spring5.plot(subplots = True,figsize=(10,20))
#
# NameError: name 'Spring5' is not defined

# %%
Fall5.plot(subplots = True,figsize=(10,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-8752fe325bb0> in <module>()
# ----> 1 Fall5.plot(subplots = True,figsize=(10,20))
#
# NameError: name 'Fall5' is not defined

# %%
#Spring.T.plot(subplots = True,figsize=(10,20))
#Fall.T.plot(subplots = True,figsize=(10,20))
#Spring5.T.plot(subplots = True,figsize=(10,20))
#Fall5.T.plot(subplots = True,figsize=(10,20))
